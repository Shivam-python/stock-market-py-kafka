# %%
import pandas as pd
import json
from time import sleep
from kafka import KafkaConsumer, KafkaProducer
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'stock_data_v2',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id='stock-group-v2',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

# # Consume messages
# for message in consumer:
#     print(f"Received: {message.value}")

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    print("object count :",count, end="\n\n")
    with s3.open("s3://<bucket_name>/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# object count : 0
#
# object count : 1
#
# object count : 2
#
# object count : 3
#
# object count : 4
#
# object count : 5
#
# object count : 6
#
# object count : 7
#
# object count : 8
#
# object count : 9
#
# object count : 10
#
# object count : 11
#
# object count : 12
#
# object count : 13
#
# object count : 14
#
# object count : 15
#
# object count : 16
#
# object count : 17
#
# object count : 18
#
# object count : 19
#
# object count : 20
#
# object count : 21
#
# object count : 22
#
# object count : 23
#
# object count : 24
#
# object count : 25
#
# object count : 26
#
# object count : 27
#
# object count : 28
#
# object count : 29
#
# object count : 30
#
# object count : 31
#
# object count : 32
#
# object count : 33
#
# object count : 34
#
# object count : 35
#
# object count : 36
#
# object count : 37
#
# object count : 38
#
# object count : 39
#
# object count : 40
#
# object count : 41
#
# object count : 42
#
# object count : 43
#
# object count : 44
#
# object count : 45
#
# object count : 46
#
# object count : 47
#
# object count : 48
#
# object count : 49
#
# object count : 50
#
# object count : 51
#
# object count : 52
#
# object count : 53
#
# object count : 54
#
# object count : 55
#
# object count : 56
#
# object count : 57
#
# object count : 58
#
# object count : 59
#
# object count : 60
#
# object count : 61
#
# object count : 62
#
# object count : 63
#
# object count : 64
#
# object count : 65
#
# object count : 66
#
# object count : 67
#
# object count : 68
#
# object count : 69
#
# object count : 70
#
# object count : 71
#
# object count : 72
#
# object count : 73
#
# object count : 74
#
# object count : 75
#
# object count : 76
#
# object count : 77
#
# object count : 78
#
# object count : 79
#
# object count : 80
#
# object count : 81
#
# object count : 82
#
# object count : 83
#
# object count : 84
#
# object count : 85
#
# object count : 86
#
# object count : 87
#
# object count : 88
#
# object count : 89
#
# object count : 90
#
# object count : 91
#
# object count : 92
#
# object count : 93
#
# object count : 94
#
# object count : 95
#
# object count : 96
#
# object count : 97
#
# object count : 98
#
# object count : 99
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     print("object count :",count, end="\n\n")
#       3     with s3.open("s3://pykaf-stock-app/stock_market_{}.json".format(count), 'w') as file:
#
# File ~\OneDrive\Documents\stock-market-py-kafka\env\lib\site-packages\kafka\consumer\group.py:1197, in KafkaConsumer.__next__(self)
#    1195     return self.next_v1()
#    1196 else:
# -> 1197     return self.next_v2()
#
# File ~\OneDrive\Documents\stock-market-py-kafka\env\lib\site-packages\kafka\consumer\group.py:1205, in KafkaConsumer.next_v2(self)
#    1203     self._iterator = self._message_generator_v2()
#    1204 try:
# -> 1205     return next(self._iterator)
#    1206 except StopIteration:
#    1207     self._iterator = None
#
# File ~\OneDrive\Documents\stock-market-py-kafka\env\lib\site-packages\kafka\consumer\group.py:1120, in KafkaConsumer._message_generator_v2(self)
#    1118 def _message_generator_v2(self):
#    1119     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1120     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1121     for tp, records in six.iteritems(record_map):
#    1122         # Generators are stateful, and it is possible that the tp / records
#    1123         # here may become stale during iteration -- i.e., we seek to a
#    1124         # different offset, pause consumption, or lose assignment.
#    1125         for record in records:
#    1126             # is_fetchable(tp) should handle assignment changes and offset
#    1127             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1128             # outer function destroying the existing iterator/generator
#    1129             # via self._iterator = None
#
# File ~\OneDrive\Documents\stock-market-py-kafka\env\lib\site-packages\kafka\consumer\group.py:657, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     655 remaining = timeout_ms
#     656 while not self._closed:
# --> 657     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     658     if records:
#     659         return records
#
# File ~\OneDrive\Documents\stock-market-py-kafka\env\lib\site-packages\kafka\consumer\group.py:706, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     703     self._client.poll(timeout_ms=0)
#     705 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 706 self._client.poll(timeout_ms=timeout_ms)
#     707 # after the long poll, we should check whether the group needs to rebalance
#     708 # prior to returning data so that the group can stabilize faster
#     709 if self._coordinator.need_rejoin():
#
# File ~\OneDrive\Documents\stock-market-py-kafka\env\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\OneDrive\Documents\stock-market-py-kafka\env\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\AppData\Local\Programs\Python\Python39\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
